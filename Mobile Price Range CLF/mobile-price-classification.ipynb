# %% [markdown]
# Data Download

# %%
import numpy as numpy
import pandas as pd

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %% [markdown]
# Data Preprocessing

# %%
train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
train['price_range']
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
xtrain=train.drop('price_range',axis=1)
xtrain
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
ytrain=train['price_range']
ytrain.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
xtest=test.drop('id',axis=1)
xtest
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xtrain,ytrain, test_size = 0.20, random_state =5)

# %%
x_test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 51             1760     0          1.4         1   5       0          63
# 1327            948     0          2.3         0  14       0          22
# 1488            959     1          1.3         1   0       0          36
# 1432            630     0          2.0         0   9       1          14
# 417             651     1          0.8         1   2       1          63
# ...             ...   ...          ...       ...  ..     ...         ...
# 1251           1317     0          1.8         1   2       0          43
# 275            1220     0          2.9         0   3       0          62
# 1114            781     1          1.3         1   1       0          64
# 1751            508     1          1.3         0   1       0          50
# 72              605     0          1.0         0   8       1           9
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y_test
# Out:
# 51      2
# 1327    3
# 1488    3
# 1432    0
# 417     1
#        ..
# 1251    3
# 275     2
# 1114    3
# 1751    1
# 72      0
# Name: price_range, Length: 400, dtype: int64

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# MODEL EVALUATION

# %% [markdown]
# 1) Decision Tree

# %%
from sklearn import tree 
mod1 = tree.DecisionTreeClassifier(max_depth=16)
mod1.fit(x_train, y_train)
mod1.predict(x_test)
# Out:
# array([2, 3, 3, 0, 1, 1, 2, 3, 2, 1, 2, 0, 3, 3, 2, 0, 1, 2, 1, 3, 0, 1,
#        3, 1, 3, 2, 2, 3, 0, 1, 0, 2, 0, 0, 3, 2, 1, 3, 3, 0, 3, 1, 3, 2,
#        3, 3, 0, 0, 2, 2, 3, 3, 2, 2, 1, 0, 0, 0, 2, 1, 0, 0, 2, 3, 1, 1,
#        2, 2, 2, 1, 2, 2, 0, 0, 0, 2, 1, 1, 1, 3, 1, 3, 1, 1, 2, 1, 1, 1,
#        2, 1, 3, 0, 3, 3, 2, 2, 1, 2, 3, 3, 3, 1, 1, 0, 3, 2, 0, 2, 0, 3,
#        0, 2, 0, 0, 1, 1, 2, 3, 2, 0, 1, 2, 1, 0, 3, 2, 0, 0, 1, 3, 2, 3,
#        2, 0, 1, 0, 2, 0, 0, 1, 1, 3, 0, 1, 3, 1, 0, 1, 0, 1, 1, 1, 2, 0,
#        2, 2, 2, 1, 0, 3, 3, 3, 2, 1, 1, 0, 1, 0, 0, 2, 2, 2, 2, 0, 2, 3,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 2, 3, 1, 3, 2, 3, 1, 1, 1, 3, 1, 2, 2,
#        0, 1, 2, 0, 3, 0, 2, 3, 3, 2, 1, 0, 1, 3, 1, 3, 1, 1, 2, 1, 1, 3,
#        3, 0, 3, 2, 0, 1, 1, 1, 1, 3, 2, 2, 1, 3, 2, 1, 3, 1, 0, 3, 0, 1,
#        1, 1, 1, 0, 2, 2, 0, 0, 3, 3, 0, 3, 2, 0, 0, 3, 3, 2, 3, 0, 1, 1,
#        0, 2, 3, 3, 3, 3, 0, 1, 1, 2, 2, 1, 3, 0, 3, 3, 2, 0, 1, 1, 1, 3,
# ...

# %%
mod1.score(x_test,y_test)*100
# Out:
# 85.25

# %% [markdown]
# 2) Random Forest(Max Depth=16)

# %%
 from sklearn.ensemble import RandomForestClassifier
 mod2 = RandomForestClassifier(n_estimators=99, max_depth=16, random_state=42)
 mod2.fit(x_train, y_train)
 mod2.predict(x_test)
# Out:
# array([2, 3, 3, 0, 1, 1, 2, 3, 2, 0, 3, 0, 3, 3, 2, 0, 1, 2, 1, 3, 0, 1,
#        3, 2, 2, 2, 2, 3, 0, 1, 1, 2, 0, 0, 3, 2, 0, 3, 2, 0, 3, 1, 2, 2,
#        3, 3, 0, 0, 2, 2, 2, 3, 2, 1, 2, 0, 1, 0, 2, 1, 0, 0, 2, 3, 1, 1,
#        2, 2, 2, 1, 2, 2, 0, 0, 0, 2, 2, 1, 0, 3, 1, 3, 1, 1, 1, 1, 0, 1,
#        3, 1, 3, 0, 3, 3, 2, 2, 1, 2, 3, 3, 3, 1, 1, 0, 3, 2, 0, 2, 0, 3,
#        0, 2, 0, 0, 2, 1, 2, 3, 3, 0, 1, 2, 1, 0, 3, 3, 0, 0, 1, 3, 2, 2,
#        2, 0, 1, 0, 2, 0, 0, 2, 2, 3, 0, 1, 3, 1, 0, 0, 0, 1, 1, 1, 1, 0,
#        2, 2, 2, 1, 0, 3, 3, 3, 2, 1, 1, 0, 1, 0, 0, 2, 2, 1, 2, 0, 2, 2,
#        0, 2, 3, 0, 0, 0, 2, 2, 3, 2, 3, 1, 3, 2, 3, 1, 1, 1, 3, 2, 2, 2,
#        0, 1, 2, 0, 3, 0, 2, 3, 3, 3, 1, 0, 1, 3, 1, 3, 1, 1, 2, 1, 1, 2,
#        3, 0, 3, 2, 0, 2, 1, 1, 0, 3, 3, 2, 1, 3, 2, 1, 2, 1, 1, 3, 0, 1,
#        2, 0, 1, 0, 2, 2, 0, 0, 3, 3, 0, 2, 2, 0, 0, 3, 3, 2, 3, 0, 2, 1,
#        0, 2, 3, 3, 3, 3, 0, 1, 1, 1, 2, 0, 3, 0, 3, 3, 2, 0, 1, 1, 1, 3,
# ...

# %%
mod2.score(x_test,y_test)*100
# Out:
# 90.75

# %% [markdown]
# 3) KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
mod3 = KNeighborsClassifier(n_neighbors=3)
mod3.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=mod3.predict(x_test)
y_pred
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 1, 0, 2, 1, 0, 1, 3, 2, 0, 1, 1, 0, 1, 0, 0,
#        1, 0, 2, 0, 1, 3, 0, 0, 1, 1, 2, 0, 3, 0, 1, 3, 2, 0, 2, 0, 0, 3,
#        3, 3, 2, 0, 1, 2, 3, 3, 0, 3, 0, 0, 0, 1, 2, 0, 2, 0, 0, 1, 0, 0,
#        1, 1, 2, 1, 0, 2, 0, 0, 0, 2, 2, 1, 0, 3, 1, 3, 2, 1, 2, 0, 0, 0,
#        3, 1, 3, 0, 1, 3, 3, 3, 0, 2, 3, 1, 3, 0, 1, 1, 3, 2, 0, 2, 0, 3,
#        0, 1, 0, 2, 0, 0, 3, 3, 0, 1, 1, 1, 0, 0, 3, 3, 0, 0, 0, 0, 2, 1,
#        2, 0, 0, 1, 0, 0, 0, 0, 0, 3, 0, 1, 1, 0, 0, 1, 2, 0, 2, 2, 1, 0,
#        1, 3, 0, 1, 0, 2, 3, 2, 2, 1, 0, 0, 0, 0, 1, 0, 3, 3, 0, 0, 0, 1,
#        0, 0, 2, 1, 0, 1, 2, 1, 2, 3, 2, 1, 1, 2, 3, 0, 1, 2, 1, 2, 1, 1,
#        0, 0, 2, 0, 2, 0, 1, 3, 3, 2, 2, 0, 0, 3, 2, 2, 2, 0, 2, 0, 3, 1,
#        3, 0, 2, 2, 0, 1, 0, 2, 0, 0, 2, 0, 2, 3, 2, 1, 2, 1, 1, 3, 0, 0,
#        1, 0, 0, 0, 2, 1, 0, 0, 3, 3, 0, 2, 2, 1, 1, 3, 3, 1, 2, 2, 3, 0,
#        0, 2, 3, 2, 1, 3, 0, 2, 0, 1, 0, 0, 3, 0, 2, 3, 0, 1, 1, 1, 2, 3,
# ...

# %%
mod3.score(x_test,y_test)*100
# Out:
# 49.25

# %% [markdown]
# 4) Random forest(Max depth=32)

# %%
 mod4 = RandomForestClassifier(n_estimators=99, max_depth=32, random_state=42)
 mod4.fit(x_train, y_train)
 mod4.predict(x_test)
# Out:
# array([2, 3, 3, 0, 1, 1, 2, 3, 2, 1, 3, 0, 3, 3, 2, 0, 1, 2, 1, 3, 0, 1,
#        3, 2, 2, 2, 2, 3, 0, 1, 1, 1, 0, 0, 3, 2, 0, 3, 2, 0, 3, 1, 2, 2,
#        3, 3, 0, 0, 2, 2, 2, 3, 2, 1, 2, 0, 1, 0, 2, 1, 0, 0, 3, 3, 1, 1,
#        2, 2, 2, 1, 2, 2, 0, 0, 0, 2, 2, 1, 0, 3, 1, 3, 1, 1, 1, 1, 0, 1,
#        2, 1, 3, 0, 3, 3, 2, 2, 1, 2, 3, 3, 3, 1, 1, 0, 3, 2, 0, 2, 0, 3,
#        0, 2, 0, 0, 1, 1, 2, 3, 3, 0, 1, 2, 1, 0, 3, 2, 0, 0, 1, 3, 2, 2,
#        2, 0, 1, 0, 2, 0, 0, 2, 2, 3, 0, 1, 3, 1, 0, 0, 0, 1, 2, 1, 1, 0,
#        2, 2, 2, 1, 0, 3, 3, 3, 2, 1, 1, 0, 1, 0, 0, 2, 2, 2, 2, 0, 2, 2,
#        0, 1, 3, 0, 0, 0, 2, 2, 3, 2, 3, 1, 3, 2, 3, 1, 1, 1, 3, 2, 2, 2,
#        0, 1, 2, 0, 3, 0, 2, 3, 3, 3, 1, 0, 1, 3, 1, 3, 1, 1, 2, 1, 1, 2,
#        3, 0, 3, 2, 0, 2, 1, 1, 0, 3, 3, 2, 1, 3, 2, 1, 2, 1, 1, 3, 0, 1,
#        2, 0, 1, 0, 2, 2, 0, 0, 3, 3, 0, 2, 2, 0, 0, 3, 3, 2, 3, 0, 2, 1,
#        0, 2, 3, 3, 3, 3, 0, 1, 1, 1, 2, 0, 3, 0, 3, 3, 1, 0, 1, 1, 1, 3,
# ...

# %%
mod4.score(x_test,y_test)*100
# Out:
# 89.75

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# In summary, out of the 3 models we tested, we find the most accurate results with our 2nd model i.e Decision tree with a maxdepth 16.
#
# We can also improve on our existing model by implementing methods of data engineering and feature selection during the pre-processing stage. Using neural networks should improve the accuracy and precision of the predictions.
